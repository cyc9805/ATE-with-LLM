# %% [markdown]
# # Create data with shorter text

# %%
import glob
import os
import pandas as pd
import xml.etree.ElementTree as ET

# configuration
annotation_path = 'distribution/annotation_files/'
raw_data_path = 'distribution/raw_abstract_txt/'
############################################

domain_name = 'Computational Linguistics'
pattern = os.path.join(annotation_path, '*[0-9]*')

pd_ds = pd.DataFrame(columns=['doc_id', 'doc_segment_id', 'annotator_id', 'text', 'label', 'category', 'domain'])


for path in glob.glob(pattern):
    annotator_id = int(os.path.basename(path)[-1])
    for doc in os.listdir(path):
        pattern = os.path.join(path, doc, '*.xml')
        for file in glob.glob(pattern):
            abstract_file_path = file.replace(os.path.join('annotation_files', f'annotator{annotator_id}'), 'raw_abstract_txt')
            abstract_tree = ET.parse(abstract_file_path)
            abstract_root = abstract_tree.getroot()
            abstract_texts = list(map(lambda x: x.text, abstract_root.findall('.//S')))

            tree = ET.parse(file)
            root = tree.getroot()
            annotation_texts = list(map(lambda x: x.text, root.findall('.//S')))
            if len(abstract_texts) != len(annotation_texts):
                raise ValueError(f'Length of abstract_texts and annotation_texts are different: {len(abstract_texts)} != {len(annotation_texts)}')
            
            doc_segment_id = os.path.basename(file).split('.')[0]

            for i in root.iter():
                if i.tag == 'S':
                    text = abstract_texts.pop(0)
    
                if i.tag == 'term':
                    category = i.attrib['class']
                    term = i.text
                    pd_ds.loc[len(pd_ds)] = [doc, doc_segment_id, annotator_id, text, term, category, domain_name]

pd_ds.head(10)
# Out:
#   doc_id  doc_segment_id  annotator_id  \
# 0     87  P87-1022_abstr             2
# 1     87  P87-1022_abstr             2
# 2     87  P87-1022_abstr             2
# 3     87  P87-1022_abstr             2
# 4     87  P87-1022_abstr             2
# 5     87  P87-1022_abstr             2
# 6     87  P87-1022_abstr             2
# 7     87  P87-1022_abstr             2
# 8     87  P87-1022_abstr             2
# 9     87  P87-1022_abstr             2
#
#                                                 text  \
# 0  In this paper we present a formalization of th...
# 1  In this paper we present a formalization of th...
# 2  In this paper we present a formalization of th...
# 3  In this paper we present a formalization of th...
# 4  In this paper we present a formalization of th...
# 5  As described in [GJW86], the process of center...
# 6  As described in [GJW86], the process of center...
# 7  As described in [GJW86], the process of center...
# 8  As described in [GJW86], the process of center...
# 9  As described in [GJW86], the process of center...
#
#                                  label category                     domain
# 0                   centering approach     tech  Computational Linguistics
# 1                attentional structure    other  Computational Linguistics
# 2                            discourse    other  Computational Linguistics
# 3                    discourse context    other  Computational Linguistics
# 4                             pronouns    other  Computational Linguistics
# 5                            attention    other  Computational Linguistics
# 6                             entities    other  Computational Linguistics
# 7                            discourse    other  Computational Linguistics
# 8  intersentential transitional states    other  Computational Linguistics
# 9                           continuing    other  Computational Linguistics

# %%
delimiter = ';;; '
pd.set_option('display.max_colwidth', 500)
grouped_df = pd_ds.groupby(['text', 'annotator_id']).agg({
    'domain': 'first',
    'doc_id': 'first',
    'doc_segment_id': 'first',
    'category': delimiter.join,  # Assuming you want unique categories joined by space
    'label': delimiter.join
}).reset_index()

grouped_df['category'] = grouped_df['category'].apply(lambda x: x.split(delimiter))
grouped_df['label'] = grouped_df['label'].apply(lambda x: x.split(delimiter))
grouped_df.head(10)
# Out:
#                                                                                                                                 text  \
# 0       (Ramshaw and Marcus, 1995) have introduced a convenient data representation for chunking by converting it to a tagging task.
# 1             (ii) High quality translation via word sense disambiguation and accurate word order generation of the target language.
# 2             (ii) High quality translation via word sense disambiguation and accurate word order generation of the target language.
# 3                   (iii) Rapid system development and porting to new domains via knowledge-based automated acquisition of grammars.
# 4                   (iii) Rapid system development and porting to new domains via knowledge-based automated acquisition of grammars.
# 5  /Soames 1979/ provides some counterexamples to the theory of natural language presuppositions that is presented in /Gazdar 1979/.
# 6  /Soames 1979/ provides some counterexamples to the theory of natural language presuppositions that is presented in /Gazdar 1979/.
# 7                                            A 'lexicalized' grammar naturally follows from the extended domain of locality of TAGs.
# 8   A central problem of word sense disambiguation (WSD) is the lack of manually sense-tagged data required for supervised learning.
# 9   A central problem of word sense disambiguation (WSD) is the lack of manually sense-tagged data required for supervised learning.
#
#    annotator_id                     domain doc_id  doc_segment_id  \
# 0             2  Computational Linguistics     99  E99-1023_abstr
# 1             1  Computational Linguistics     01  H01-1041_abstr
# 2             2  Computational Linguistics     01  H01-1041_abstr
# 3             1  Computational Linguistics     01  H01-1041_abstr
# 4             2  Computational Linguistics     01  H01-1041_abstr
# 5             1  Computational Linguistics     88  C88-2086_abstr
# 6             2  Computational Linguistics     88  C88-2086_abstr
# 7             2  Computational Linguistics     89  H89-1036_abstr
# 8             1  Computational Linguistics     03  P03-1058_abstr
# 9             2  Computational Linguistics     03  P03-1058_abstr
#
#                     category  \
# 0         [tech, tech, tech]
# 1  [tech, tech, tech, other]
# 2  [tech, tech, tech, other]
# 3        [tech, other, tech]
# 4         [tech, tech, tech]
# 5                    [other]
# 6                    [other]
# 7          [lr, other, tech]
# 8           [tech, lr, tech]
# 9           [tech, lr, tech]
#
#                                                                                              label
# 0                                                    [data representation, chunking, tagging task]
# 1                 [translation, word sense disambiguation, word order generation, target language]
# 2                 [translation, word sense disambiguation, word order generation, target language]
# 3           [Rapid system development, domains, knowledge-based automated acquisition of grammars]
# 4  [system development, porting to new domains, knowledge-based automated acquisition of grammars]
# 5                                                     [theory of natural language presuppositions]
# 6                                                               [natural language presuppositions]
# 7                                       ['lexicalized' grammar, extended domain of locality, TAGs]
# 8               [word sense disambiguation (WSD), manually sense-tagged data, supervised learning]
# 9               [word sense disambiguation (WSD), manually sense-tagged data, supervised learning]

# %%
annotator_1_df = grouped_df[grouped_df['annotator_id'] == 1].reset_index()
annotator_2_df = grouped_df[grouped_df['annotator_id'] == 2].reset_index()

# %%
print(len(annotator_1_df))
print(len(annotator_2_df))
# Out:
# 870
# 1242

# %%
indexes = []
for i, annotator_1_df_text, annotator_1_df_terms in zip(annotator_1_df.index, annotator_1_df['text'], annotator_1_df['label']):
    for annotator_2_df_text, annotator_2_df_terms in zip(annotator_2_df['text'], annotator_2_df['label']):
        if annotator_1_df_terms == annotator_2_df_terms and annotator_1_df_text == annotator_2_df_text:
            indexes.append(i)
            
agreed_df = annotator_1_df.iloc[indexes]
agreed_df.head(10)
# Out:
#     index  \
# 0       1
# 3       8
# 4      11
# 7      21
# 8      24
# 10     30
# 12     39
# 13     41
# 15     45
# 17     51
#
#                                                                                                                                                                                                                                                                                                                                                          text  \
# 0                                                                                                                                                                                                                                      (ii) High quality translation via word sense disambiguation and accurate word order generation of the target language.
# 3                                                                                                                                                                                                                            A central problem of word sense disambiguation (WSD) is the lack of manually sense-tagged data required for supervised learning.
# 4                                                                                                                                                                                                                                                                          A customized interface for browsing and editing was also designed and implemented.
# 7                                                                                                                                                                                                                                                                     A grammar model for concurrent, object-oriented natural language parsing is introduced.
# 8                                                                                                                                                                                                                       A language learning experiment showed that assessors can differentiate native from non-native language essays in less than 100 words.
# 10                                                                                                                                                                                                                                                                               A method for producing such phrases from a word-aligned corpora is proposed.
# 12                                                                                                                                                                                                                                                                                       A new, flexible inference method for Horn logic program is proposed.
# 13                                                                                                                                                                                                                                A novel bootstrapping approach to Named Entity (NE) tagging using concept-based seeds and successive learners is presented.
# 15  A novel method for adding linguistic annotation to corpora is presented which involves using a statistical POS tagger in conjunction with unsupervised structure finding methods to derive notions of noun group, verb group, and so on which is inherently extensible to more sophisticated annotation, and does not require a pre-tagged corpus to fit.
# 17                                                                                                                                                                                                                                                                                             A pilot system has shown great effectiveness of this approach.
#
#     annotator_id                     domain doc_id  doc_segment_id  \
# 0              1  Computational Linguistics     01  H01-1041_abstr
# 3              1  Computational Linguistics     03  P03-1058_abstr
# 4              1  Computational Linguistics     90  J90-3002_abstr
# 7              1  Computational Linguistics     94  C94-1061_abstr
# 8              1  Computational Linguistics     01  H01-1042_abstr
# 10             1  Computational Linguistics     05  H05-1095_abstr
# 12             1  Computational Linguistics     94  C94-1077_abstr
# 13             1  Computational Linguistics     03  N03-2025_abstr
# 15             1  Computational Linguistics     94  A94-1011_abstr
# 17             1  Computational Linguistics     92  C92-3165_abstr
#
#                                             category  \
# 0                          [tech, tech, tech, other]
# 3                                   [tech, lr, tech]
# 4                                             [tech]
# 7                                      [model, tech]
# 8                       [other, other, other, other]
# 10                                       [other, lr]
# 12                                     [tech, other]
# 13                         [tech, tech, other, tech]
# 15  [other, lr, tech, tech, other, other, other, lr]
# 17                                           [other]
#
#                                                                                                                                                       label
# 0                                                                          [translation, word sense disambiguation, word order generation, target language]
# 3                                                                        [word sense disambiguation (WSD), manually sense-tagged data, supervised learning]
# 4                                                                                                                                               [interface]
# 7                                                                                     [grammar model, concurrent, object-oriented natural language parsing]
# 8                                                                  [language learning experiment, assessors, native from non-native language essays, words]
# 10                                                                                                                          [phrases, word-aligned corpora]
# 12                                                                                                                   [inference method, Horn logic program]
# 13                                                            [bootstrapping approach, Named Entity (NE) tagging, concept-based seeds, successive learners]
# 15  [linguistic annotation, corpora, statistical POS tagger, unsupervised structure finding methods, noun group, verb group, annotation, pre-tagged corpus]
# 17                                                                                                                                           [pilot system]

# %%
# Select indexes of the rows that are not in the agreed_df
exclude_indexes = [i for i in range(len(annotator_1_df)) if i not in indexes]
only_in_annotator_1_df = annotator_1_df.iloc[exclude_indexes]
only_in_annotator_1_df.head(10)
# Out:
#     index  \
# 1       3
# 2       5
# 5      15
# 6      18
# 9      28
# 11     35
# 14     43
# 16     48
# 20     61
# 22     67
#
#                                                                                                                                                                                                                                                                                                 text  \
# 1                                                                                                                                                                                   (iii) Rapid system development and porting to new domains via knowledge-based automated acquisition of grammars.
# 2                                                                                                                                                                  /Soames 1979/ provides some counterexamples to the theory of natural language presuppositions that is presented in /Gazdar 1979/.
# 5                                                                                                                                                           A dialogue acquisition and tracking algorithm is presented along with a description of its implementation in a voice interactive system.
# 6   A further reduction in the search space is achieved by using semantic rather than syntactic categories on the terminal and non-terminal edges, thereby reducing the amount of ambiguity and thus the number of edges, since only edges with a valid semantic interpretation are ever introduced.
# 9                                                                                                                                     A method for error correction of ill-formed input is described that acquires dialogue patterns in typical usage and uses these patterns to predict new inputs.
# 11                                                                                                                                                A new approach for Interactive Machine Translation where the author interacts during the creation or the modification of the document is proposed.
# 14                                                                              A novel evaluation scheme is proposed which accounts for the effect of polysemy on the clusters, offering us a good insight into the potential and limitations of semantically classifying undisambiguated SCF data.
# 16                                                                                                                                                                                        A parser incorporating the control structure and the parsing strategies is currently under implementation.
# 20                                                                                                                                                                       A research program is described in which a particular representational format for meaning is tested as broadly as possible.
# 22                                                                                                                                                                         A series of tests are described that show the power of the error correction methodology when stereotypic dialogue occurs.
#
#     annotator_id                     domain doc_id  doc_segment_id  \
# 1              1  Computational Linguistics     01  H01-1041_abstr
# 2              1  Computational Linguistics     88  C88-2086_abstr
# 5              1  Computational Linguistics     86  J86-1002_abstr
# 6              1  Computational Linguistics     92  A92-1027_abstr
# 9              1  Computational Linguistics     86  J86-1002_abstr
# 11             1  Computational Linguistics     88  C88-2160_abstr
# 14             1  Computational Linguistics     03  P03-1009_abstr
# 16             1  Computational Linguistics     84  P84-1047_abstr
# 20             1  Computational Linguistics     78  T78-1001_abstr
# 22             1  Computational Linguistics     86  J86-1002_abstr
#
#                                                     category  \
# 1                                        [tech, other, tech]
# 2                                                    [other]
# 5                                        [tech, other, tech]
# 6   [other, other, other, other, other, other, other, other]
# 9                                [tech, other, other, other]
# 11                                      [tech, other, other]
# 14                         [tech, other, other, tech, other]
# 16                               [tech, other, other, other]
# 20                                                   [other]
# 22                                             [tech, other]
#
#                                                                                                                                   label
# 1                                                [Rapid system development, domains, knowledge-based automated acquisition of grammars]
# 2                                                                                          [theory of natural language presuppositions]
# 5                                               [dialogue acquisition and tracking algorithm, implementation, voice interactive system]
# 6   [reduction in the search space, semantic, syntactic categories, terminal and non-terminal edges, ambiguity, edges, edges, semantic]
# 9                                                                     [error correction, ill-formed input, dialogue patterns, patterns]
# 11                                                                                  [Interactive Machine Translation, author, document]
# 14                                          [evaluation scheme, polysemy, clusters, semantically classifying, undisambiguated SCF data]
# 16                                                                      [parser, control structure, parsing strategies, implementation]
# 20                                                                                                [representational format for meaning]
# 22                                                                                 [error correction methodology, stereotypic dialogue]

# %%
annotator_1_df_only_doc_id = annotator_1_df['doc_id'].unique()
only_in_annotator_2_df = annotator_2_df[[doc_id not in annotator_1_df_only_doc_id for doc_id in annotator_2_df['doc_id']]]
only_in_annotator_2_df.head(10)
# Out:
#     index  \
# 0       0
# 4       7
# 6      10
# 8      13
# 9      14
# 11     17
# 13     20
# 15     23
# 17     26
# 18     27
#
#                                                                                                                                                                                                                                                                                                                         text  \
# 0                                                                                                                                                                                               (Ramshaw and Marcus, 1995) have introduced a convenient data representation for chunking by converting it to a tagging task.
# 4                                                                                                                                                                                                                                    A 'lexicalized' grammar naturally follows from the extended domain of locality of TAGs.
# 6   A construction-specific approach also aids in task-specific language development by allowing a language definition that is natural in terms of the task domain to be interpreted directly without compilation into a uniform grammar formalism, thus greatly speeding the testing of changes to the language definition.
# 8                                                                                                                             A declarative formalism is presented which permits direct mappings of one feature structure into another, and illustrative examples are given of its application to areas of current interest.
# 9              A demonstration (in UNIX) for Applied Natural Language Processing emphasizes components put to novel technical uses in intelligent computer-assisted morphological analysis (ICALL), including disambiguated morphological analysis and lemmatized indexing for an aligned bilingual corpus of word examples.
# 11                                                                                                                                                                                                           A flexible parser can deal with input that deviates from its grammar, in addition to input that conforms to it.
# 13                                                                                                                                                                                                                                                       A general parsing strategy for 'lexicalized' grammars is discussed.
# 15                                                                                                                                                                                                                                                                  A grammar of this form will be said to be 'lexicalized'.
# 17                                                                                                                                                                                                                                                                            A lexicons for French is also being developed.
# 18                                                                                                                                  A major concern in corpus based approaches is that the applicability of the acquired knowledge may be limited by some feature of the corpus, in particular, the notion of text 'domain'.
#
#     annotator_id                     domain doc_id  doc_segment_id  \
# 0              2  Computational Linguistics     99  E99-1023_abstr
# 4              2  Computational Linguistics     89  H89-1036_abstr
# 6              2  Computational Linguistics     81  P81-1033_abstr
# 8              2  Computational Linguistics     91  E91-1050_abstr
# 9              2  Computational Linguistics     97  A97-1020_abstr
# 11             2  Computational Linguistics     81  P81-1033_abstr
# 13             2  Computational Linguistics     89  H89-1036_abstr
# 15             2  Computational Linguistics     89  H89-1036_abstr
# 17             2  Computational Linguistics     89  H89-1036_abstr
# 18             2  Computational Linguistics     97  A97-1015_abstr
#
#                                     category  \
# 0                         [tech, tech, tech]
# 4                          [lr, other, tech]
# 6   [tech, model, other, other, tech, model]
# 8                       [other, other, tech]
# 9        [other, tech, tech, tech, tech, lr]
# 11                  [tech, other, lr, other]
# 13                                [tech, lr]
# 15                                      [lr]
# 17                               [lr, other]
# 18           [tech, other, other, lr, other]
#
#                                                                                                                                                                                                               label
# 0                                                                                                                                                                     [data representation, chunking, tagging task]
# 4                                                                                                                                                        ['lexicalized' grammar, extended domain of locality, TAGs]
# 6                                                                                                 [language development, language definition, task domain, uniform grammar formalism, testing, language definition]
# 8                                                                                                                                                              [declarative formalism, mappings, feature structure]
# 9   [UNIX, Applied Natural Language Processing, intelligent computer-assisted morphological analysis (ICALL), disambiguated morphological analysis, lemmatized indexing, aligned bilingual corpus of word examples]
# 11                                                                                                                                                                                  [parser, input, grammar, input]
# 13                                                                                                                                                                       [parsing strategy, 'lexicalized' grammars]
# 15                                                                                                                                                                                                        [grammar]
# 17                                                                                                                                                                                               [lexicons, French]
# 18                                                                                                                                             [corpus based approaches, knowledge, feature, corpus, text 'domain']

# %%
# Check the number of the rows in each dataframe
len_agreed_df = len(agreed_df)
len_only_in_annotator_1_df = len(only_in_annotator_1_df)
len_only_in_annotator_2_df = len(only_in_annotator_2_df)
len_total_df = len_agreed_df + len_only_in_annotator_1_df + len_only_in_annotator_2_df

print(f'Number of the rows in the agreed_df: {len_agreed_df}')
print(f'Number of the rows in the only_in_annotator_1_df: {len_only_in_annotator_1_df}')
print(f'Number of the rows in the only_in_annotator_2_df: {len_only_in_annotator_2_df}')

print(f'Ratio of the agreed_df: {len_agreed_df / (len_total_df)}')
# Out:
# Number of the rows in the agreed_df: 367
# Number of the rows in the only_in_annotator_1_df: 503
# Number of the rows in the only_in_annotator_2_df: 351
# Ratio of the agreed_df: 0.30057330057330056

# %%
# Split DataFrame into training, validation, and test set
import random
seed=42
validation_dataset_ratio = 0.1

len_validation_dataset = len_total_df * validation_dataset_ratio
len_only_annotator_df = len_only_in_annotator_1_df + len_only_in_annotator_2_df

random.seed(seed)
only_in_annotator_1_df_val_idx = random.sample(only_in_annotator_1_df.index.to_list(), int(round(len_validation_dataset * len_only_in_annotator_1_df/len_only_annotator_df, 0)))
only_in_annotator_2_df_val_idx = random.sample(only_in_annotator_2_df.index.to_list(), int(round(len_validation_dataset * len_only_in_annotator_2_df/len_only_annotator_df, 0)))

test_df = agreed_df
validation_df = pd.concat([
    only_in_annotator_1_df.loc[only_in_annotator_1_df_val_idx],
    only_in_annotator_2_df.loc[only_in_annotator_2_df_val_idx]
])
train_df = pd.concat([
    only_in_annotator_1_df.drop(only_in_annotator_1_df_val_idx),
    only_in_annotator_2_df.drop(only_in_annotator_2_df_val_idx)
])

# %%
print(len(test_df))
print(len(validation_df))
print(len(train_df))
print(f'Ratio of validation dataset: {len(validation_df) / (len(train_df)+len(validation_df)+len(test_df))}')
# Out:
# 367
# 122
# 732
# Ratio of validation dataset: 0.09991809991809991

# %%
# Convert DataFrame to huggingface dataset and save it to specified directory
from datasets import Dataset, DatasetDict

hf_save_dir = 'huggingface'
os.makedirs(hf_save_dir, exist_ok=True)

train_dataset = Dataset.from_pandas(train_df, preserve_index=False)
validation_dataset = Dataset.from_pandas(validation_df, preserve_index=False)
test_dataset = Dataset.from_pandas(test_df, preserve_index=False)

dataset = DatasetDict({
    'train': train_dataset,
    'validation': validation_dataset,
    'test': test_dataset
})

dataset.save_to_disk(hf_save_dir)
# Out:
# Saving the dataset (1/1 shards): 100%|██████████| 732/732 [00:00<00:00, 29407.21 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 122/122 [00:00<00:00, 14841.07 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 367/367 [00:00<00:00, 1622.55 examples/s]
